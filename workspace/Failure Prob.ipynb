# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-da7d0f78860e> in <module>
# ----> 1 import numpy as np
#       2 import scipy
#       3 import matplotlib.pyplot as plt
#
# ImportError: No module named 'numpy'
